# %% [markdown]
# <a href="https://colab.research.google.com/github/hanumaisyaah/BasicAppX/blob/master/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Practicum** **Session**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv 
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Mark-Neverland.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Mark-Neverland.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
from IPython.core.pylabtools import figsize
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1 = (384,0), pt2=(510, 150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1 = (200,200), pt2=(300, 300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center = (100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1 = (0,0), pt2=(512,512),  color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
black_img8 = black_img
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img8, text='Hanum', org=(10,500), fontFace = font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img8)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) 
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# TASK **SECTION**

# %% [markdown]
# No. 1

# %%
plt.figure(figsize=(2,2))
plt.imshow(img3)

# %% [markdown]
# No. 2

# %%
# Red-Green Only
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,2] = 0
plt.imshow(img3)

# %%
# Green-Blue Only
imgGB = img
imgGB = cv.cvtColor(img,cv.COLOR_BGR2RGB)
imgGB[:,:,0] = 0
plt.imshow(imgGB)

# %% [markdown]
# No. 3

# %%
#Show image row 10-100, column 10-100
imgRowColumns = cv.cvtColor(img, cv.COLOR_BGR2RGB)
imgRowColumns = imgRowColumns[10:100, 10:100]
plt.imshow(imgRowColumns)

# %% [markdown]
# No. 4

# %%
#Show image row 5-30, all columns, Green channel only
green = cv.cvtColor(img, cv.COLOR_BGR2RGB)
green = green[5:30]
green[:,:,0] = 0
green[:,:,2] = 0
plt.imshow(green)

# %% [markdown]
# No. 5

# %%
#5 boxes of different size and colors in one image
gbr = cv.imread('/content/drive/MyDrive/PCVK_MM/Haechan.jpg')
gbr = cv.cvtColor(gbr, cv.COLOR_BGR2RGB)
cv.rectangle(gbr, pt1=(0,0), pt2=(200,200), color=(255,255,255), thickness=10)
cv.rectangle(gbr, pt1=(600,300), pt2=(400,600), color=(0,255,0), thickness=10)
cv.rectangle(gbr, pt1=(100,300), pt2=(600,200), color=(255,255,0), thickness=10)
cv.rectangle(gbr, pt1=(500,200), pt2=(600,300), color=(255,0,0), thickness=10)
cv.rectangle(gbr, pt1=(600,300), pt2=(800,300), color=(0,255,255), thickness=10)
plt.imshow(gbr)

# %% [markdown]
# No. 6

# %%
#Show the image upside-down
gbrUpsideDown = cv.flip(gbr, 0)
plt.imshow(gbrUpsideDown)

# %% [markdown]
# No. 7

# %%
#Make rectangles and circles on face
rc = cv.imread('/content/drive/MyDrive/PCVK_MM/dream.jpg')
rc = cv.cvtColor(rc, cv.COLOR_BGR2RGB)
cv.rectangle(rc, pt1=(100,100), pt2=(200,200), color=(0,0,255), thickness=10)
cv.circle(rc, center=(520,200), radius=50, color=(255,0,0), thickness=10)
plt.imshow(rc)

# %% [markdown]
# No. 8

# %%
#Create a rectangle on lower left on Channel B
imgB = cv.cvtColor(img, cv.COLOR_BGR2RGB)
height = imgB.shape[0]
width = imgB.shape[1]
imgB[:,:,0] = 0
imgB[:,:,1] = 0
cv.rectangle(imgB, pt1=(0,height), pt2=(100,400), color=(255,255,255), thickness=5)
plt.imshow(imgB)

# %% [markdown]
# No. 9

# %%
#Complete the writing on black image
black_img3=np.zeros(shape=(512,512,3),dtype=np.int32)
font = cv.FONT_HERSHEY_COMPLEX_SMALL
cv.putText(black_img3,text='Hanum :)',org=(10,250),fontFace=font,fontScale=2,color=(255,255,255),thickness=1,lineType=cv.LINE_AA)
plt.imshow(black_img3)
